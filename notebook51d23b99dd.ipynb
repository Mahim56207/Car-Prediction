# %% [markdown]
# # ColdSite-DTI — configurable binary grid (Kaggle)
#
# One notebook for any of the four baseline/ours models, on either dataset, over any subset
# of the four split types -- so two Kaggle accounts (or two commits of the same account) can
# each own a share of the work without ever training the same cell twice.
#
# | model | role |
# |---|---|
# | DeepDTA | accuracy anchor (no attention, never audited) |
# | ColdSite-DTI | our model |
# | HyperAttentionDTI | published model under audit |
# | MolTrans | published model under audit (deferred until this notebook existed) |
#
# **Why binary.** DeepDTA, HyperAttentionDTI and MolTrans only predict binding / non-binding
# in this project's recipe, so the audit table can only compare models on one metric --
# AUROC -- if every model does the same task. A pair counts as binding at
# **pKd >= threshold** (`BINARY_THRESHOLD` in `src/model/dataset.py`: DAVIS 7.0, KIBA 12.1).
#
# ## Before you run
#
# | Setting | Value |
# |---|---|
# | Accelerator | **GPU** (T4 x2 if available -- more GPUs, more parallel splits) |
# | Internet | **On** |
# | Environment | **Pin to original** |
# | How to run | **Save Version -> Save & Run All (Commit)** |
# | Settings cell | edit `DATASET`, `MODELS`, `SPLIT_SUBSET`, `SEEDS` below -- see presets there |
#
# ## The loop you will repeat -- read this
#
# Every commit starts in a **fresh, empty container**. Finished cells do not carry over by
# themselves. So:
#
# 1. **First commit:** leave `RESTORE_FROM = None` and commit.
# 2. When it finishes: open that version -> **Output** -> download the results zip, and
#    upload it as a Kaggle **Dataset** (name it so you know which account/model/dataset it
#    is -- e.g. `coldsite-moltrans-davis-results`).
# 3. **Every later commit:** attach that dataset (Add Input), set `RESTORE_FROM` in the
#    restore cell, and commit. Finished cells are skipped; interrupted ones are retrained.
# 4. After each commit, add the new output to the dataset (**New Version** of it), so the
#    next restore has everything.
#
# **The notebook stops itself at 11 hours.** Kaggle ends a commit at 12, and a commit cut off
# mid-cell may not save its output. A cell stopped mid-training is retrained on the next
# commit.
#
# **MolTrans checkpoints are big** -- about 250 MB each (vs. ~2.5 MB for the other three
# models; its decoder has a 78,192 -> 512 linear layer). A 12-cell MolTrans grid is ~3 GB.
# Plan the restore-dataset size and the Drive backup accordingly.

# %% [markdown]
# ## 1. Settings — the only cell you should need to edit

# %%
# ============================================================================
# SETTINGS
# ============================================================================

DATASET = 'davis'                 # 'davis' | 'kiba'
MODELS = ['moltrans']             # any subset of: 'deepdta', 'coldsite_dti', 'hyperattentiondti', 'moltrans'
SPLIT_SUBSET = ['random', 'cold_drug', 'cold_target', 'cold_pair']  # which split types THIS run trains
SEEDS = [1, 2, 3]

# --- presets, for reference -- delete or ignore whichever you are not using ------------
# Account 2, MolTrans on DAVIS (first job -- all four splits, nobody else is training them):
#   DATASET = 'davis'; MODELS = ['moltrans']
#   SPLIT_SUBSET = ['random', 'cold_drug', 'cold_target', 'cold_pair']
#
# Account 2, MolTrans on KIBA (after DAVIS is done -- HALF the splits; agree the other
# half with account 1 first, see CLAUDE.md):
#   DATASET = 'kiba'; MODELS = ['moltrans']
#   SPLIT_SUBSET = ['random', 'cold_drug']                      # example half
#
# Account 1, once the DAVIS 36-grid is 36/36 -- KIBA, the three DAVIS-grid models, the
# OTHER half of the splits:
#   DATASET = 'kiba'; MODELS = ['deepdta', 'coldsite_dti', 'hyperattentiondti']
#   SPLIT_SUBSET = ['cold_target', 'cold_pair']                 # the half account 2 is not training
# -----------------------------------------------------------------------------------------

ALL_SPLITS = ['random', 'cold_drug', 'cold_target', 'cold_pair']
KNOWN_MODELS = ['deepdta', 'coldsite_dti', 'hyperattentiondti', 'moltrans']

assert DATASET in ('davis', 'kiba'), DATASET
assert MODELS and all(m in KNOWN_MODELS for m in MODELS), \
    f'MODELS must be a non-empty subset of {KNOWN_MODELS}, got {MODELS}'
assert SPLIT_SUBSET and all(s in ALL_SPLITS for s in SPLIT_SUBSET), \
    f'SPLIT_SUBSET must be a non-empty subset of {ALL_SPLITS}, got {SPLIT_SUBSET}'
assert SEEDS, 'SEEDS must not be empty'

TOTAL_CELLS = len(MODELS) * len(SPLIT_SUBSET) * len(SEEDS)
print(f'{DATASET} | models: {", ".join(MODELS)} | splits: {", ".join(SPLIT_SUBSET)} | seeds: {SEEDS}')
print(f'{TOTAL_CELLS} cells this run ({len(MODELS)} model(s) x {len(SPLIT_SUBSET)} split(s) x {len(SEEDS)} seed(s))')
# Out:
# davis | models: moltrans | splits: random, cold_drug, cold_target, cold_pair | seeds: [1, 2, 3]
# 12 cells this run (1 model(s) x 4 split(s) x 3 seed(s))

# %% [markdown]
# ## 2. Check the GPU(s)

# %%
import time
START = time.time()          # the 11-hour self-stop is measured from here

import torch

assert torch.cuda.is_available(), 'No CUDA. Settings -> Accelerator -> GPU.'
N_GPU = torch.cuda.device_count()
for i in range(N_GPU):
    p = torch.cuda.get_device_properties(i)
    print(f'GPU {i}: {p.name}, {p.total_memory/1e9:.1f} GB')
print('torch  :', torch.__version__)

# Measured peak memory on a 1000-residue protein (STATUS.md), from the DAVIS 36-grid:
#   ColdSite-DTI  batch 64 -> 8.7 GB, 16 -> 2.3 GB
#   HyperAttentionDTI  batch 32 -> ~5 GB; 8 x accum 4 is the same effective batch
#   DeepDTA  batch 256 -> 0.7 GB
#   MolTrans  not yet profiled on a full split -- stays at the vendored batch size (16)
#   rather than guessing a larger one on a bigger GPU.
big = torch.cuda.get_device_properties(0).total_memory / 1e9 >= 14
COLDSITE_BATCH = 64 if big else 16
HAT_BATCH, HAT_ACCUM = (32, 1) if big else (8, 4)
DEEPDTA_BATCH = 256
MOLTRANS_BATCH = 16
print(f'batches: ColdSite {COLDSITE_BATCH}, HAT {HAT_BATCH}x{HAT_ACCUM}, '
      f'DeepDTA {DEEPDTA_BATCH}, MolTrans {MOLTRANS_BATCH}')
# Out:
# GPU 0: Tesla T4, 15.6 GB
# GPU 1: Tesla T4, 15.6 GB
# torch  : 2.10.0+cu128
# batches: ColdSite 64, HAT 32x1, DeepDTA 256, MolTrans 16

# %% [markdown]
# ## 3. Clone the repo
#
# Pinned to `main` on the fork. If this run trains MolTrans, the cell also refuses to
# continue on a checkout that predates `src/model/train_moltrans.py` -- that file has to be
# pushed to `origin/main` before Kaggle can clone it.

# %%
import os

REPO = 'https://github.com/Mahim56207/ColdSite-DTI_New.git'
WORK = '/kaggle/working'
SRC  = f'{WORK}/ColdSite-DTI_New'

if not os.path.exists(SRC):
    # !git clone --branch main {REPO} {SRC}
os.chdir(SRC)
# !git pull origin main
# !pip install -q tabulate subword-nmt

import importlib, src.model.dataset as _ds
importlib.reload(_ds)
assert hasattr(_ds, 'BINARY_THRESHOLD'), (
    'This checkout predates the binary-label fix -- ColdSite-DTI would crash. '
    'Re-run this cell so git pull fetches main.')
if 'moltrans' in MODELS:
    assert os.path.exists('src/model/train_moltrans.py'), (
        'This checkout has no src/model/train_moltrans.py -- push that commit to '
        'origin/main before running MolTrans here, then re-run this cell.')

RESULTS = f'{WORK}/results'
os.makedirs(RESULTS, exist_ok=True)
print()
# !git log --oneline -1
print('results ->', RESULTS)
# Out:
# Cloning into '/kaggle/working/ColdSite-DTI_New'...
# remote: Enumerating objects: 812, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 812 (delta 23), reused 38 (delta 11), pack-reused 746 (from 1)
# Receiving objects: 100% (812/812), 184.71 MiB | 19.89 MiB/s, done.
# Resolving deltas: 100% (395/395), done.
# From https://github.com/Mahim56207/ColdSite-DTI_New
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# e252048 (HEAD -> main, origin/main, origin/HEAD) Add MolTrans trainer and a configurable multi-model Kaggle grid notebook
# results -> /kaggle/working/results

# %% [markdown]
# ## 4. Fetch the DeepDTA source files
#
# `build_splits` needs these for both datasets regardless of which models this run trains.

# %%
BASE = 'https://raw.githubusercontent.com/hkmztrk/DeepDTA/master/data'
for ds in ('davis', 'kiba'):
    os.makedirs(f'src/data/baselines/deepdta/data/{ds}', exist_ok=True)
    for fname in ('ligands_can.txt', 'proteins.txt', 'Y'):
        target = f'src/data/baselines/deepdta/data/{ds}/{fname}'
        if not os.path.exists(target):
            # !curl -sL {BASE}/{ds}/{fname} -o {target}
# !python -m src.data.load_data
# Out:
# davis: 30056 measured pairs, 68 unique drugs, 442 unique targets, Y range [5.000, 10.796]
# kiba: 118254 measured pairs, 2111 unique drugs, 229 unique targets, Y range [0.000, 17.200]

# %% [markdown]
# ## 5. Build the splits — and verify they match
#
# Every cell in this project has to come from the same splits, whichever account or model
# trains it. The counts below were verified on a MacBook, on Colab and on Kaggle.

# %%
# !python -m src.data.build_splits 2>&1 | grep -E 'davis|kiba|leakage'

import pandas as pd

EXPECTED = {
    'davis': {
        'random':      (21039, 3006, 6011),
        'cold_drug':   (21658, 2652, 5746),
        'cold_target': (21080, 2992, 5984),
        'cold_pair':   (15190,  264, 1144),
    },
    'kiba': {
        'random':      (82778, 11825, 23651),
        'cold_drug':   (83807, 12073, 22374),
        'cold_target': (85452, 10701, 22101),
        'cold_pair':   (58041,  1334,  4375),
    },
}

problems = []
for split in ALL_SPLITS:
    expected = EXPECTED[DATASET][split]
    got = tuple(len(pd.read_csv(f'data/splits/{DATASET}/{split}/{part}.csv'))
                for part in ('train', 'valid', 'test'))
    marker = 'OK' if got == expected else 'MISMATCH'
    flag = '  <- this run trains it' if split in SPLIT_SUBSET else ''
    if got != expected:
        problems.append(f'{split}: expected {expected}, got {got}')
    print(f"{split:12s} {str(got):26s} {marker}{flag}")
assert not problems, f'{DATASET} splits differ from the rest of the project:\n  ' + '\n  '.join(problems)
print(f'\n{DATASET} splits match. Safe to train.')
# Out:
# === Building splits for davis ===
# Saved data/splits/davis/random/  train=21039  valid=3006  test=6011
# Saved data/splits/davis/cold_drug/  train=21658  valid=2652  test=5746
# Saved data/splits/davis/cold_target/  train=21080  valid=2992  test=5984
# Saved data/splits/davis/cold_pair/  train=15190  valid=264  test=1144
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# === Building splits for kiba ===
# Saved data/splits/kiba/random/  train=82778  valid=11825  test=23651
# Saved data/splits/kiba/cold_drug/  train=83807  valid=12073  test=22374
# Saved data/splits/kiba/cold_target/  train=85452  valid=10701  test=22101
# Saved data/splits/kiba/cold_pair/  train=58041  valid=1334  test=4375
# cold_drug: no leakage across train/valid/test -- OK
# cold_target: no leakage across train/valid/test -- OK
# cold_pair: no leakage across train/valid/test -- OK
# random       (21039, 3006, 6011)        OK  <- this run trains it
# cold_drug    (21658, 2652, 5746)        OK  <- this run trains it
# cold_target  (21080, 2992, 5984)        OK  <- this run trains it
# cold_pair    (15190, 264, 1144)         OK  <- this run trains it
#
# davis splits match. Safe to train.

# %% [markdown]
# ## 6. Restore results from a previous commit
#
# `None` on the first commit. After that, attach the dataset holding the previous output and
# put its path here. Only model files are copied, and nothing already present is
# overwritten.

# %%
import shutil, glob

# e.g. '/kaggle/input/coldsite-moltrans-davis-results'
RESTORE_FROM = None

if RESTORE_FROM:
    assert os.path.isdir(RESTORE_FROM), f'not a directory: {RESTORE_FROM}'
    copied = skipped = 0
    for src in glob.glob(f'{RESTORE_FROM}/**/*', recursive=True):
        name = os.path.basename(src)
        if not name.endswith(('.pt', '_results.json', '_history.json')):
            continue
        dst = os.path.join(RESULTS, name)
        if os.path.exists(dst):
            skipped += 1
            continue
        shutil.copy2(src, dst)
        copied += 1
    print(f'restored {copied} file(s), left {skipped} already present')
else:
    print('RESTORE_FROM is None -- starting from an empty results folder.')
# Out:
# RESTORE_FROM is None -- starting from an empty results folder.

# %% [markdown]
# ## 7. The runner
#
# Each GPU works through its own queue of commands in order; the GPUs run in parallel. This
# run's `SPLIT_SUBSET` is divided across the available GPUs; each GPU trains every model in
# `MODELS`, cheapest first, over its share of splits. Every line is prefixed with where it
# comes from -- GPU, model, split, seed and cell number -- so a line never needs scrolling
# back to place. Each finished cell gets a `✓` line with its test AUROC and the running total,
# and every 10 minutes a `STATUS` line shows every GPU at once: search the log for `STATUS`.
#
# At the 11-hour mark it stops launching new work and ends anything still running, so the
# commit can save.

# %%
import subprocess, threading, glob, json, re
from src.model.checkpoint_naming import checkpoint_path, results_path, run_tag

DEADLINE = START + 11 * 3600
STATUS_EVERY = 600          # seconds between STATUS lines

splits_list = list(SPLIT_SUBSET)
SHARE = {str(g): splits_list[g::N_GPU] for g in range(N_GPU)}
SHARE = {g: s for g, s in SHARE.items() if s}   # drop a GPU with nothing to do

MODEL_NAME = {'src.model.train_deepdta': 'DeepDTA', 'src.model.run_grid': 'ColdSite',
              'src.model.train_hyperattentiondti': 'HAT', 'src.model.train_moltrans': 'MolTrans'}
HEADER = re.compile(r'^\w+/(\w+)/seed(\d+)\s*$')          # run_grid: a cell starts
SKIPPED = re.compile(r'^\[skip\] \w+/(\w+)/seed(\d+)')     # run_grid: a cell was done
EPOCH = re.compile(r'^\s*(?:epoch|Epoch)\s+(\d+)')
SAVED = re.compile(r'Saved -> (\S+_results\.json)')


def hours_left():
    return (DEADLINE - time.time()) / 3600


def cells_done():
    done = 0
    for model in MODELS:
        for split in SPLIT_SUBSET:
            for seed in SEEDS:
                tag = run_tag(DATASET, split, 'binary', seed)
                if os.path.exists(results_path(RESULTS, tag, model=model)):
                    done += 1
    return done


def _arg(cmd, flag):
    return cmd[cmd.index(flag) + 1] if flag in cmd else '-'


def _cells_in(cmd):
    if cmd[3] == 'src.model.run_grid':
        return len(_arg(cmd, '--splits').split(',')) * len(_arg(cmd, '--seeds').split(','))
    return 1


def run_parallel(queues, label):
    """queues: {gpu: [command, ...]}. Returns True if the deadline cut it short."""
    current, state = {}, {'deadline': False}
    where = {g: {'model': '-', 'split': '-', 'seed': '-', 'epoch': '-', 'cell': 0,
                 'total': sum(_cells_in(c) for c in q)} for g, q in queues.items()}

    def tag(g):
        w = where[g]
        return f"[GPU{g} {w['model']} {w['split']} s{w['seed']} · cell {w['cell']}/{w['total']}]"

    def begin_cell(g, split, seed):
        where[g].update(split=split, seed=seed, epoch='-')
        where[g]['cell'] += 1

    def worker(gpu, commands):
        env = {**os.environ, 'CUDA_VISIBLE_DEVICES': gpu, 'PYTHONUNBUFFERED': '1'}
        with open(f'{WORK}/{label}_gpu{gpu}.log', 'a') as log:
            for cmd in commands:
                if time.time() > DEADLINE:
                    return
                module = cmd[3]
                where[gpu]['model'] = MODEL_NAME.get(module, module)
                if module != 'src.model.run_grid':          # one command = one cell
                    begin_cell(gpu, _arg(cmd, '--split'), _arg(cmd, '--seed'))
                proc = subprocess.Popen(cmd, env=env, stdout=subprocess.PIPE,
                                        stderr=subprocess.STDOUT, text=True, bufsize=1)
                current[gpu] = proc
                for line in proc.stdout:
                    if module == 'src.model.run_grid':      # follow run_grid's own cells
                        m = HEADER.match(line) or SKIPPED.match(line)
                        if m:
                            begin_cell(gpu, m.group(1), m.group(2))
                    m = EPOCH.match(line)
                    if m:
                        where[gpu]['epoch'] = m.group(1)
                    print(f'{tag(gpu)} {line}', end='', flush=True)
                    log.write(line)
                    log.flush()
                    m = SAVED.search(line)
                    if m:
                        try:
                            auc = json.load(open(m.group(1)))['test_metrics'].get('auroc')
                            auc = f'{auc:.4f}'
                        except Exception:
                            auc = '?'
                        print(f'  ✓ {tag(gpu)} finished -- test AUROC {auc}   '
                              f'[{cells_done()}/{TOTAL_CELLS} cells complete]', flush=True)
                code_ = proc.wait()
                if code_ != 0 and not state['deadline']:
                    print(f'{tag(gpu)} !! exited {code_}: {" ".join(cmd[3:])}', flush=True)

    threads = [threading.Thread(target=worker, args=(g, q), daemon=True)
               for g, q in queues.items()]
    for t in threads:
        t.start()
    last_status = 0.0
    while any(t.is_alive() for t in threads):
        if time.time() - last_status >= STATUS_EVERY:
            last_status = time.time()
            parts = [f"GPU{g}: {w['model']} {w['split']} s{w['seed']} "
                     f"cell {w['cell']}/{w['total']} epoch {w['epoch']}"
                     for g, w in where.items()]
            print(f"\n=== STATUS {time.strftime('%H:%M')} | " + ' | '.join(parts)
                  + f' | {cells_done()}/{TOTAL_CELLS} complete | {hours_left():.1f} h left ===\n',
                  flush=True)
        if time.time() > DEADLINE and not state['deadline']:
            state['deadline'] = True
            print('\n*** 11-hour mark: stopping so this commit can save its output. '
                  'Unfinished cells are retrained next commit. ***\n', flush=True)
            for proc in list(current.values()):
                if proc.poll() is None:
                    proc.terminate()
        time.sleep(15)
    return state['deadline']


def deepdta_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_deepdta',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--task', 'binary', '--seed', str(seed),
            '--batch-size', str(DEEPDTA_BATCH), '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


def coldsite_cmd(splits):
    return ['python', '-u', '-m', 'src.model.run_grid', '--datasets', DATASET,
            '--splits', ','.join(splits), '--seeds', ','.join(map(str, SEEDS)),
            '--task', 'binary', '--epochs', '100', '--min-epochs', '10',
            '--batch-size', str(COLDSITE_BATCH), '--results-dir', RESULTS]


def hat_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_hyperattentiondti',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--seed', str(seed),
            '--batch-size', str(HAT_BATCH), '--accum-steps', str(HAT_ACCUM),
            '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


def moltrans_cmd(split, seed):
    return ['python', '-u', '-m', 'src.model.train_moltrans',
            '--split-dir', f'data/splits/{DATASET}/{split}', '--dataset', DATASET,
            '--split', split, '--seed', str(seed),
            '--batch-size', str(MOLTRANS_BATCH), '--min-epochs', '10', '--epochs', '100',
            '--checkpoint-dir', RESULTS, '--results-dir', RESULTS, '--skip-if-done']


# Cheapest / fastest-signal model first, when it is part of this run.
MODEL_ORDER = ['deepdta', 'moltrans', 'coldsite_dti', 'hyperattentiondti']


def build_queue(splits):
    queue = []
    for model in MODEL_ORDER:
        if model not in MODELS:
            continue
        if model == 'deepdta':
            queue += [deepdta_cmd(split, seed) for split in splits for seed in SEEDS]
        elif model == 'coldsite_dti':
            queue.append(coldsite_cmd(splits))
        elif model == 'hyperattentiondti':
            queue += [hat_cmd(split, seed) for split in splits for seed in SEEDS]
        elif model == 'moltrans':
            queue += [moltrans_cmd(split, seed) for split in splits for seed in SEEDS]
    return queue


for gpu, splits in SHARE.items():
    print(f'GPU {gpu} -> {", ".join(splits)}  ({", ".join(MODELS)})')
print(f'{hours_left():.1f} h left before the self-stop')
# Out:
# GPU 0 -> random, cold_target  (moltrans)
# GPU 1 -> cold_drug, cold_pair  (moltrans)
# 11.0 h left before the self-stop

# %% [markdown]
# ## 8. Launch

# %%
if hours_left() < 0.5:
    print(f'Skipped: only {hours_left():.1f} h left. Commit again with the restore cell set.')
else:
    queues = {gpu: build_queue(splits) for gpu, splits in SHARE.items()}
    cut_short = run_parallel(queues, 'grid')
    print('\n' + ('CUT SHORT by the deadline -- commit again with RESTORE_FROM set'
                  if cut_short else 'Queue finished on every GPU.'))
# Out:
# === STATUS 08:45 | GPU0: - - s- cell 0/6 epoch - | GPU1: - - s- cell 0/6 epoch - | 0/12 complete | 11.0 h left ===
#
# [GPU0 MolTrans random s1 · cell 1/6]   train  21,039 pairs  8.5% positive  <- data/splits/davis/random/train.csv
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   train  21,658 pairs  9.4% positive  <- data/splits/davis/cold_drug/train.csv
# [GPU0 MolTrans random s1 · cell 1/6]   valid   3,006 pairs  8.3% positive  <- data/splits/davis/random/valid.csv
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   valid   2,652 pairs  4.9% positive  <- data/splits/davis/cold_drug/valid.csv
# [GPU0 MolTrans random s1 · cell 1/6]   test    6,011 pairs  7.7% positive  <- data/splits/davis/random/test.csv
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   test    5,746 pairs  6.0% positive  <- data/splits/davis/cold_drug/test.csv
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]   device        cuda (Tesla T4, 14.6 GB)
# [GPU0 MolTrans random s1 · cell 1/6]   batch size    16 (vendored: 16)
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   device        cuda (Tesla T4, 14.6 GB)
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   batch size    16 (vendored: 16)
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 20/1353 loss 0.6085
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 20/1314 loss 0.5999
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 40/1353 loss 0.5526
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 40/1314 loss 0.5517
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 60/1353 loss 0.5121
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 60/1314 loss 0.5271
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 80/1353 loss 0.4916
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 80/1314 loss 0.5051
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 100/1353 loss 0.4723
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 100/1314 loss 0.4861
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 120/1353 loss 0.4640
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 120/1314 loss 0.4685
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 140/1353 loss 0.4514
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 140/1314 loss 0.4514
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 160/1353 loss 0.4366
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 160/1314 loss 0.4419
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 180/1353 loss 0.4258
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 180/1314 loss 0.4330
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 200/1353 loss 0.4174
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 200/1314 loss 0.4240
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 220/1353 loss 0.4068
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 220/1314 loss 0.4155
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 240/1353 loss 0.3982
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 240/1314 loss 0.4055
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 260/1353 loss 0.3909
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 260/1314 loss 0.3972
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 280/1353 loss 0.3866
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 280/1314 loss 0.3888
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 300/1353 loss 0.3815
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 300/1314 loss 0.3792
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 320/1353 loss 0.3776
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 320/1314 loss 0.3738
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 340/1353 loss 0.3728
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 340/1314 loss 0.3712
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 360/1353 loss 0.3689
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 360/1314 loss 0.3647
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 380/1353 loss 0.3643
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 380/1314 loss 0.3596
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 400/1353 loss 0.3615
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 400/1314 loss 0.3562
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 420/1353 loss 0.3569
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 420/1314 loss 0.3525
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 440/1353 loss 0.3547
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 440/1314 loss 0.3513
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 460/1353 loss 0.3512
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 460/1314 loss 0.3486
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 480/1353 loss 0.3489
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 480/1314 loss 0.3464
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 500/1353 loss 0.3458
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 500/1314 loss 0.3452
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 520/1353 loss 0.3438
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 520/1314 loss 0.3416
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 540/1353 loss 0.3423
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 540/1314 loss 0.3379
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 560/1353 loss 0.3408
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 560/1314 loss 0.3343
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 580/1353 loss 0.3395
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 600/1353 loss 0.3370
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 580/1314 loss 0.3315
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 620/1353 loss 0.3348
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 600/1314 loss 0.3304
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 640/1353 loss 0.3321
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 620/1314 loss 0.3275
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 660/1353 loss 0.3313
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 640/1314 loss 0.3257
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 680/1353 loss 0.3288
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 660/1314 loss 0.3245
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 700/1353 loss 0.3274
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 680/1314 loss 0.3223
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 720/1353 loss 0.3245
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 700/1314 loss 0.3201
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 740/1353 loss 0.3224
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 720/1314 loss 0.3179
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 760/1353 loss 0.3201
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 740/1314 loss 0.3155
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 780/1353 loss 0.3190
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 760/1314 loss 0.3144
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 800/1353 loss 0.3175
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 780/1314 loss 0.3128
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 820/1353 loss 0.3174
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 800/1314 loss 0.3102
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 840/1353 loss 0.3164
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 820/1314 loss 0.3087
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 860/1353 loss 0.3148
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 840/1314 loss 0.3078
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 880/1353 loss 0.3140
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 860/1314 loss 0.3067
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 900/1353 loss 0.3131
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 880/1314 loss 0.3054
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 920/1353 loss 0.3128
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 900/1314 loss 0.3051
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 940/1353 loss 0.3124
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 920/1314 loss 0.3036
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 960/1353 loss 0.3104
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 940/1314 loss 0.3023
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 980/1353 loss 0.3092
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 960/1314 loss 0.2994
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1000/1353 loss 0.3076
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 980/1314 loss 0.2989
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1020/1353 loss 0.3066
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1000/1314 loss 0.2974
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1040/1353 loss 0.3058
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1020/1314 loss 0.2965
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1060/1353 loss 0.3046
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1040/1314 loss 0.2960
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1080/1353 loss 0.3034
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1060/1314 loss 0.2946
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1100/1353 loss 0.3028
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1080/1314 loss 0.2940
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1120/1353 loss 0.3020
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1100/1314 loss 0.2936
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1140/1353 loss 0.3003
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1120/1314 loss 0.2925
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1160/1353 loss 0.2987
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1140/1314 loss 0.2916
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1180/1353 loss 0.2977
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1160/1314 loss 0.2904
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1200/1353 loss 0.2961
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1180/1314 loss 0.2907
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1220/1353 loss 0.2953
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1200/1314 loss 0.2905
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1240/1353 loss 0.2939
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1220/1314 loss 0.2894
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1260/1353 loss 0.2918
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1240/1314 loss 0.2887
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1280/1353 loss 0.2913
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1260/1314 loss 0.2871
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1300/1353 loss 0.2910
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1280/1314 loss 0.2864
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1320/1353 loss 0.2903
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1300/1314 loss 0.2861
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 train batch 1314/1314 loss 0.2859
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1340/1353 loss 0.2903
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 train batch 1353/1353 loss 0.2902
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 20/188 loss 0.2453
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 20/166 loss 0.1280
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 40/188 loss 0.2414
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 40/166 loss 0.1581
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 60/188 loss 0.2247
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 60/166 loss 0.1567
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 80/188 loss 0.2228
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 80/166 loss 0.1731
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 100/188 loss 0.2212
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 100/166 loss 0.1947
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 120/188 loss 0.2254
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 120/166 loss 0.2050
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 140/188 loss 0.2321
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 140/166 loss 0.1951
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 160/166 loss 0.1903
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 1 valid batch 166/166 loss 0.1894
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   epoch   1 train 0.2902 val 0.1894 auroc 0.6705 auprc 0.1222 accuracy 0.9510
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 160/188 loss 0.2291
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 180/188 loss 0.2288
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 1 valid batch 188/188 loss 0.2287
# [GPU0 MolTrans random s1 · cell 1/6]   epoch   1 train 0.2859 val 0.2287 auroc 0.8465 auprc 0.3505 accuracy 0.9125
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 20/1353 loss 0.2103
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 20/1314 loss 0.2290
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 40/1353 loss 0.2483
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 40/1314 loss 0.2407
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 60/1353 loss 0.2542
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 60/1314 loss 0.2292
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 80/1353 loss 0.2505
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 80/1314 loss 0.2274
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 100/1353 loss 0.2568
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 100/1314 loss 0.2236
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 120/1353 loss 0.2500
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 120/1314 loss 0.2282
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 140/1353 loss 0.2436
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 140/1314 loss 0.2351
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 160/1353 loss 0.2419
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 160/1314 loss 0.2343
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 180/1353 loss 0.2466
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 180/1314 loss 0.2337
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 200/1353 loss 0.2495
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 200/1314 loss 0.2317
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 220/1353 loss 0.2469
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 220/1314 loss 0.2321
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 240/1353 loss 0.2465
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 240/1314 loss 0.2295
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 260/1353 loss 0.2477
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 260/1314 loss 0.2261
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 280/1353 loss 0.2463
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 280/1314 loss 0.2234
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 300/1353 loss 0.2462
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 300/1314 loss 0.2206
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 320/1353 loss 0.2449
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 320/1314 loss 0.2200
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 340/1353 loss 0.2423
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 340/1314 loss 0.2230
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 360/1353 loss 0.2401
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 360/1314 loss 0.2209
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 380/1353 loss 0.2391
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 380/1314 loss 0.2251
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 400/1353 loss 0.2383
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 400/1314 loss 0.2240
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 420/1353 loss 0.2373
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 420/1314 loss 0.2267
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 440/1353 loss 0.2397
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 440/1314 loss 0.2254
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 460/1353 loss 0.2387
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 460/1314 loss 0.2271
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 480/1353 loss 0.2379
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 480/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 500/1353 loss 0.2378
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 500/1314 loss 0.2287
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 520/1353 loss 0.2372
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 520/1314 loss 0.2275
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 540/1353 loss 0.2389
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 540/1314 loss 0.2278
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 560/1353 loss 0.2395
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 560/1314 loss 0.2296
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 580/1353 loss 0.2388
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 580/1314 loss 0.2294
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 600/1353 loss 0.2380
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 600/1314 loss 0.2290
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 620/1353 loss 0.2390
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 620/1314 loss 0.2293
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 640/1353 loss 0.2387
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 640/1314 loss 0.2291
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 660/1353 loss 0.2376
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 660/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 680/1353 loss 0.2359
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 680/1314 loss 0.2277
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 700/1353 loss 0.2365
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 700/1314 loss 0.2278
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 720/1353 loss 0.2366
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 720/1314 loss 0.2267
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 740/1353 loss 0.2368
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 740/1314 loss 0.2264
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 760/1353 loss 0.2364
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 760/1314 loss 0.2260
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 780/1353 loss 0.2357
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 780/1314 loss 0.2265
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 800/1353 loss 0.2359
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 800/1314 loss 0.2282
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 820/1353 loss 0.2370
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 820/1314 loss 0.2287
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 840/1353 loss 0.2359
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 840/1314 loss 0.2298
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 860/1353 loss 0.2351
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 860/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 880/1353 loss 0.2359
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 880/1314 loss 0.2277
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 900/1353 loss 0.2358
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 900/1314 loss 0.2280
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 920/1353 loss 0.2354
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 920/1314 loss 0.2286
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 940/1353 loss 0.2352
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 940/1314 loss 0.2290
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 960/1353 loss 0.2354
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 960/1314 loss 0.2299
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 980/1353 loss 0.2358
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 980/1314 loss 0.2295
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1000/1353 loss 0.2357
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1000/1314 loss 0.2281
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1020/1353 loss 0.2348
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1020/1314 loss 0.2275
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1040/1353 loss 0.2349
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1040/1314 loss 0.2273
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1060/1353 loss 0.2359
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1060/1314 loss 0.2271
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1080/1353 loss 0.2353
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1080/1314 loss 0.2267
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1100/1353 loss 0.2353
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1100/1314 loss 0.2274
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1120/1353 loss 0.2353
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1120/1314 loss 0.2266
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1140/1353 loss 0.2361
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1140/1314 loss 0.2263
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1160/1353 loss 0.2355
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1160/1314 loss 0.2268
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1180/1353 loss 0.2348
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1180/1314 loss 0.2269
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1200/1353 loss 0.2348
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1200/1314 loss 0.2267
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1220/1353 loss 0.2348
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1220/1314 loss 0.2269
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1240/1353 loss 0.2349
#
# === STATUS 08:55 | GPU0: MolTrans random s1 cell 1/6 epoch 2 | GPU1: MolTrans cold_drug s1 cell 1/6 epoch 2 | 0/12 complete | 10.8 h left ===
#
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1240/1314 loss 0.2261
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1260/1353 loss 0.2342
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1280/1353 loss 0.2342
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1260/1314 loss 0.2250
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1300/1353 loss 0.2344
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1280/1314 loss 0.2255
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1300/1314 loss 0.2253
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 train batch 1314/1314 loss 0.2245
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1320/1353 loss 0.2344
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 20/188 loss 0.2145
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1340/1353 loss 0.2342
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 train batch 1353/1353 loss 0.2345
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 40/188 loss 0.2213
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 60/188 loss 0.2014
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 20/166 loss 0.1944
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 80/188 loss 0.1920
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 40/166 loss 0.1884
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 100/188 loss 0.1937
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 60/166 loss 0.1722
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 120/188 loss 0.2020
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 80/166 loss 0.1813
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 140/188 loss 0.2118
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 100/166 loss 0.2040
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 160/188 loss 0.2057
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 180/188 loss 0.2068
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 2 valid batch 188/188 loss 0.2063
# [GPU0 MolTrans random s1 · cell 1/6]   epoch   2 train 0.2245 val 0.2063 auroc 0.8686 auprc 0.4730 accuracy 0.9235
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 120/166 loss 0.2148
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 140/166 loss 0.2020
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 160/166 loss 0.1937
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 2 valid batch 166/166 loss 0.1928
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   epoch   2 train 0.2345 val 0.1928 auroc 0.6522 auprc 0.1011 accuracy 0.9510
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 20/1314 loss 0.1587
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 20/1353 loss 0.2163
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 40/1314 loss 0.1750
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 40/1353 loss 0.2399
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 60/1314 loss 0.1796
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 60/1353 loss 0.2313
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 80/1314 loss 0.1885
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 80/1353 loss 0.2281
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 100/1314 loss 0.1942
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 100/1353 loss 0.2288
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 120/1314 loss 0.2001
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 120/1353 loss 0.2258
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 140/1314 loss 0.1957
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 140/1353 loss 0.2273
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 160/1314 loss 0.2070
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 160/1353 loss 0.2239
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 180/1314 loss 0.2050
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 180/1353 loss 0.2241
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 200/1314 loss 0.2060
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 200/1353 loss 0.2221
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 220/1314 loss 0.2044
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 220/1353 loss 0.2200
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 240/1314 loss 0.2066
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 240/1353 loss 0.2176
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 260/1314 loss 0.2088
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 260/1353 loss 0.2159
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 280/1314 loss 0.2057
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 280/1353 loss 0.2167
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 300/1314 loss 0.2090
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 300/1353 loss 0.2130
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 320/1314 loss 0.2072
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 320/1353 loss 0.2136
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 340/1314 loss 0.2078
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 340/1353 loss 0.2122
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 360/1314 loss 0.2070
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 360/1353 loss 0.2106
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 380/1314 loss 0.2048
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 380/1353 loss 0.2130
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 400/1314 loss 0.2062
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 400/1353 loss 0.2147
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 420/1314 loss 0.2037
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 420/1353 loss 0.2152
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 440/1314 loss 0.2015
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 440/1353 loss 0.2152
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 460/1314 loss 0.2000
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 460/1353 loss 0.2149
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 480/1314 loss 0.2022
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 480/1353 loss 0.2129
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 500/1314 loss 0.2035
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 500/1353 loss 0.2116
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 520/1314 loss 0.2028
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 520/1353 loss 0.2144
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 540/1314 loss 0.2044
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 540/1353 loss 0.2156
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 560/1314 loss 0.2069
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 560/1353 loss 0.2158
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 580/1314 loss 0.2066
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 580/1353 loss 0.2158
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 600/1314 loss 0.2059
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 600/1353 loss 0.2148
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 620/1314 loss 0.2064
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 620/1353 loss 0.2148
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 640/1314 loss 0.2088
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 640/1353 loss 0.2131
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 660/1314 loss 0.2085
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 660/1353 loss 0.2134
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 680/1314 loss 0.2082
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 680/1353 loss 0.2138
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 700/1314 loss 0.2093
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 700/1353 loss 0.2138
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 720/1314 loss 0.2084
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 720/1353 loss 0.2141
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 740/1314 loss 0.2088
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 740/1353 loss 0.2147
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 760/1314 loss 0.2080
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 760/1353 loss 0.2139
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 780/1314 loss 0.2066
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 780/1353 loss 0.2140
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 800/1314 loss 0.2063
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 800/1353 loss 0.2129
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 820/1314 loss 0.2068
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 820/1353 loss 0.2126
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 840/1314 loss 0.2070
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 840/1353 loss 0.2117
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 860/1314 loss 0.2054
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 860/1353 loss 0.2113
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 880/1314 loss 0.2056
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 880/1353 loss 0.2106
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 900/1314 loss 0.2055
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 900/1353 loss 0.2102
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 920/1314 loss 0.2048
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 920/1353 loss 0.2103
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 940/1314 loss 0.2044
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 940/1353 loss 0.2106
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 960/1314 loss 0.2048
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 960/1353 loss 0.2119
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 980/1314 loss 0.2050
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 980/1353 loss 0.2122
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1000/1314 loss 0.2056
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1000/1353 loss 0.2125
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1020/1314 loss 0.2062
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1020/1353 loss 0.2113
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1040/1314 loss 0.2063
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1040/1353 loss 0.2102
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1060/1314 loss 0.2061
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1060/1353 loss 0.2098
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1080/1314 loss 0.2060
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1080/1353 loss 0.2099
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1100/1314 loss 0.2057
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1100/1353 loss 0.2098
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1120/1314 loss 0.2057
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1120/1353 loss 0.2098
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1140/1314 loss 0.2057
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1140/1353 loss 0.2100
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1160/1314 loss 0.2054
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1160/1353 loss 0.2101
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1180/1314 loss 0.2042
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1180/1353 loss 0.2092
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1200/1314 loss 0.2040
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1200/1353 loss 0.2089
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1220/1353 loss 0.2088
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1220/1314 loss 0.2032
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1240/1353 loss 0.2091
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1240/1314 loss 0.2031
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1260/1353 loss 0.2100
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1260/1314 loss 0.2041
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1280/1353 loss 0.2101
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1280/1314 loss 0.2039
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1300/1314 loss 0.2037
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 train batch 1314/1314 loss 0.2037
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1300/1353 loss 0.2106
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 20/188 loss 0.2132
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 40/188 loss 0.2219
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1320/1353 loss 0.2110
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 60/188 loss 0.2046
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 80/188 loss 0.1972
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1340/1353 loss 0.2107
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 train batch 1353/1353 loss 0.2101
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 100/188 loss 0.1977
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 120/188 loss 0.2043
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 20/166 loss 0.1638
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 140/188 loss 0.2125
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 40/166 loss 0.1818
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 160/188 loss 0.2030
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 180/188 loss 0.2018
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 3 valid batch 188/188 loss 0.2016
# [GPU0 MolTrans random s1 · cell 1/6]   epoch   3 train 0.2037 val 0.2016 auroc 0.8706 auprc 0.4880 accuracy 0.9265
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 60/166 loss 0.1688
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 80/166 loss 0.1809
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 100/166 loss 0.2070
# [GPU0 MolTrans random s1 · cell 1/6]
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 120/166 loss 0.2182
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 140/166 loss 0.2031
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 160/166 loss 0.1905
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 3 valid batch 166/166 loss 0.1879
# [GPU1 MolTrans cold_drug s1 · cell 1/6]   epoch   3 train 0.2101 val 0.1879 auroc 0.6961 auprc 0.1239 accuracy 0.9510
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 20/1314 loss 0.1429
# [GPU1 MolTrans cold_drug s1 · cell 1/6]
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 40/1314 loss 0.1490
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 20/1353 loss 0.2352
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 60/1314 loss 0.1557
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 40/1353 loss 0.1937
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 80/1314 loss 0.1615
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 60/1353 loss 0.1816
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 100/1314 loss 0.1696
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 80/1353 loss 0.1811
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 120/1314 loss 0.1669
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 100/1353 loss 0.1773
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 140/1314 loss 0.1799
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 120/1353 loss 0.1764
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 160/1314 loss 0.1802
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 140/1353 loss 0.1821
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 180/1314 loss 0.1796
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 160/1353 loss 0.1867
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 200/1314 loss 0.1762
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 180/1353 loss 0.1870
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 220/1314 loss 0.1795
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 200/1353 loss 0.1917
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 240/1314 loss 0.1804
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 220/1353 loss 0.1872
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 260/1314 loss 0.1865
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 240/1353 loss 0.1861
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 280/1314 loss 0.1867
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 260/1353 loss 0.1832
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 300/1314 loss 0.1872
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 280/1353 loss 0.1855
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 320/1314 loss 0.1860
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 300/1353 loss 0.1858
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 340/1314 loss 0.1864
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 320/1353 loss 0.1905
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 360/1314 loss 0.1865
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 340/1353 loss 0.1923
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 380/1314 loss 0.1879
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 360/1353 loss 0.1910
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 400/1314 loss 0.1866
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 380/1353 loss 0.1905
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 420/1314 loss 0.1888
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 400/1353 loss 0.1929
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 440/1314 loss 0.1873
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 420/1353 loss 0.1949
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 460/1314 loss 0.1872
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 440/1353 loss 0.1959
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 480/1314 loss 0.1870
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 460/1353 loss 0.1956
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 500/1314 loss 0.1866
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 480/1353 loss 0.1943
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 520/1314 loss 0.1861
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 500/1353 loss 0.1961
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 540/1314 loss 0.1865
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 520/1353 loss 0.1970
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 560/1314 loss 0.1856
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 540/1353 loss 0.1962
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 580/1314 loss 0.1868
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 560/1353 loss 0.1943
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 600/1314 loss 0.1868
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 580/1353 loss 0.1945
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 620/1314 loss 0.1871
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 600/1353 loss 0.1941
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 640/1314 loss 0.1861
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 620/1353 loss 0.1943
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 660/1314 loss 0.1853
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 640/1353 loss 0.1944
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 680/1314 loss 0.1859
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 660/1353 loss 0.1937
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 700/1314 loss 0.1857
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 680/1353 loss 0.1937
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 720/1314 loss 0.1852
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 700/1353 loss 0.1941
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 740/1314 loss 0.1854
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 720/1353 loss 0.1944
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 760/1314 loss 0.1856
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 740/1353 loss 0.1943
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 780/1314 loss 0.1862
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 760/1353 loss 0.1938
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 800/1314 loss 0.1858
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 780/1353 loss 0.1931
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 820/1314 loss 0.1855
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 800/1353 loss 0.1929
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 840/1314 loss 0.1864
# [GPU1 MolTrans cold_drug s1 · cell 1/6]     epoch 4 train batch 820/1353 loss 0.1921
# [GPU0 MolTrans random s1 · cell 1/6]     epoch 4 train batch 860/1314 loss 0.1873
# ...
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 60/187 loss 0.1554
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 80/187 loss 0.1605
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 100/187 loss 0.1751
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 120/187 loss 0.1909
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 140/187 loss 0.1973
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 160/187 loss 0.2044
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 180/187 loss 0.2078
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 5 valid batch 187/187 loss 0.2091
# [GPU0 MolTrans cold_target s3 · cell 6/6]   epoch   5 train 0.1711 val 0.2091 auroc 0.8316 auprc 0.3714 accuracy 0.9285
# [GPU0 MolTrans cold_target s3 · cell 6/6]
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 20/1317 loss 0.1254
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 40/1317 loss 0.1593
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 60/1317 loss 0.1561
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 80/1317 loss 0.1599
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 100/1317 loss 0.1552
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 120/1317 loss 0.1488
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 140/1317 loss 0.1511
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 160/1317 loss 0.1510
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 180/1317 loss 0.1517
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 200/1317 loss 0.1542
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 220/1317 loss 0.1518
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 240/1317 loss 0.1505
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 260/1317 loss 0.1504
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 280/1317 loss 0.1528
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 300/1317 loss 0.1526
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 320/1317 loss 0.1556
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 340/1317 loss 0.1540
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 360/1317 loss 0.1528
#
# === STATUS 19:35 | GPU0: MolTrans cold_target s3 cell 6/6 epoch 6 | GPU1: MolTrans cold_pair s3 cell 6/6 epoch 25 | 11/12 complete | 0.2 h left ===
#
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 380/1317 loss 0.1527
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 400/1317 loss 0.1551
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 420/1317 loss 0.1558
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 440/1317 loss 0.1571
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 460/1317 loss 0.1550
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 480/1317 loss 0.1556
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 500/1317 loss 0.1560
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 520/1317 loss 0.1561
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 540/1317 loss 0.1543
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 560/1317 loss 0.1551
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 580/1317 loss 0.1552
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 600/1317 loss 0.1557
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 620/1317 loss 0.1547
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 640/1317 loss 0.1542
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 660/1317 loss 0.1547
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 680/1317 loss 0.1554
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 700/1317 loss 0.1545
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 720/1317 loss 0.1539
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 740/1317 loss 0.1540
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 760/1317 loss 0.1544
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 780/1317 loss 0.1540
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 800/1317 loss 0.1551
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 820/1317 loss 0.1562
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 840/1317 loss 0.1561
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 860/1317 loss 0.1572
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 880/1317 loss 0.1569
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 900/1317 loss 0.1575
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 920/1317 loss 0.1582
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 940/1317 loss 0.1580
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 960/1317 loss 0.1579
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 980/1317 loss 0.1571
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1000/1317 loss 0.1578
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1020/1317 loss 0.1577
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1040/1317 loss 0.1570
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1060/1317 loss 0.1572
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1080/1317 loss 0.1580
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1100/1317 loss 0.1585
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1120/1317 loss 0.1582
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1140/1317 loss 0.1580
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1160/1317 loss 0.1589
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1180/1317 loss 0.1591
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1200/1317 loss 0.1587
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1220/1317 loss 0.1578
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1240/1317 loss 0.1579
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1260/1317 loss 0.1575
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1280/1317 loss 0.1578
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1300/1317 loss 0.1570
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 train batch 1317/1317 loss 0.1566
# [GPU0 MolTrans cold_target s3 · cell 6/6]
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 20/187 loss 0.1508
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 40/187 loss 0.1251
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 60/187 loss 0.1457
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 80/187 loss 0.1512
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 100/187 loss 0.1663
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 120/187 loss 0.1869
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 140/187 loss 0.1926
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 160/187 loss 0.1995
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 180/187 loss 0.2031
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 6 valid batch 187/187 loss 0.2041
# [GPU0 MolTrans cold_target s3 · cell 6/6]   epoch   6 train 0.1566 val 0.2041 auroc 0.8413 auprc 0.3783 accuracy 0.9338
# [GPU0 MolTrans cold_target s3 · cell 6/6]
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 20/1317 loss 0.1455
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 40/1317 loss 0.1314
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 60/1317 loss 0.1217
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 80/1317 loss 0.1248
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 100/1317 loss 0.1209
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 120/1317 loss 0.1203
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 140/1317 loss 0.1268
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 160/1317 loss 0.1331
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 180/1317 loss 0.1318
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 200/1317 loss 0.1306
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 220/1317 loss 0.1337
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 240/1317 loss 0.1333
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 260/1317 loss 0.1336
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 280/1317 loss 0.1334
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 300/1317 loss 0.1347
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 320/1317 loss 0.1352
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 340/1317 loss 0.1354
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 360/1317 loss 0.1358
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 380/1317 loss 0.1356
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 400/1317 loss 0.1364
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 420/1317 loss 0.1341
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 440/1317 loss 0.1332
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 460/1317 loss 0.1351
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 480/1317 loss 0.1353
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 500/1317 loss 0.1371
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 520/1317 loss 0.1366
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 540/1317 loss 0.1358
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 560/1317 loss 0.1363
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 580/1317 loss 0.1385
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 600/1317 loss 0.1371
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 620/1317 loss 0.1375
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 640/1317 loss 0.1364
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 660/1317 loss 0.1370
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 680/1317 loss 0.1377
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 700/1317 loss 0.1376
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 720/1317 loss 0.1385
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 740/1317 loss 0.1394
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 760/1317 loss 0.1397
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 780/1317 loss 0.1394
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 800/1317 loss 0.1401
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 820/1317 loss 0.1398
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 840/1317 loss 0.1399
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 860/1317 loss 0.1393
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 880/1317 loss 0.1396
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 900/1317 loss 0.1396
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 920/1317 loss 0.1389
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 940/1317 loss 0.1386
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 960/1317 loss 0.1386
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 980/1317 loss 0.1393
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1000/1317 loss 0.1402
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1020/1317 loss 0.1400
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1040/1317 loss 0.1399
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1060/1317 loss 0.1403
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1080/1317 loss 0.1412
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1100/1317 loss 0.1414
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1120/1317 loss 0.1412
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1140/1317 loss 0.1407
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1160/1317 loss 0.1409
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1180/1317 loss 0.1409
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1200/1317 loss 0.1413
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1220/1317 loss 0.1418
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1240/1317 loss 0.1420
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1260/1317 loss 0.1418
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1280/1317 loss 0.1426
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1300/1317 loss 0.1423
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 train batch 1317/1317 loss 0.1424
# [GPU0 MolTrans cold_target s3 · cell 6/6]
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 20/187 loss 0.1499
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 40/187 loss 0.1236
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 60/187 loss 0.1454
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 80/187 loss 0.1542
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 100/187 loss 0.1661
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 120/187 loss 0.1887
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 140/187 loss 0.1931
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 160/187 loss 0.1999
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 180/187 loss 0.2058
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 7 valid batch 187/187 loss 0.2076
# [GPU0 MolTrans cold_target s3 · cell 6/6]   epoch   7 train 0.1424 val 0.2076 auroc 0.8362 auprc 0.3578 accuracy 0.9311
# [GPU0 MolTrans cold_target s3 · cell 6/6]
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 20/1317 loss 0.1366
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 40/1317 loss 0.1240
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 60/1317 loss 0.1319
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 80/1317 loss 0.1378
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 100/1317 loss 0.1375
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 120/1317 loss 0.1342
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 140/1317 loss 0.1293
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 160/1317 loss 0.1275
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 180/1317 loss 0.1250
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 200/1317 loss 0.1226
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 220/1317 loss 0.1219
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 240/1317 loss 0.1232
#
# *** 11-hour mark: stopping so this commit can save its output. Unfinished cells are retrained next commit. ***
#
# [GPU0 MolTrans cold_target s3 · cell 6/6]     epoch 8 train batch 260/1317 loss 0.1237
# CUT SHORT by the deadline -- commit again with RESTORE_FROM set

# %% [markdown]
# ## 9. What landed
#
# A cell counts as complete only when both its checkpoint and its results file exist. A
# checkpoint alone is an interrupted cell, and the next commit retrains it.

# %%
import statistics as st

complete = interrupted = 0
print(f"{'model':18s} {'split':12s} {'cells':>7s}   AUROC mean +- sd")
for model in MODELS:
    for split in SPLIT_SUBSET:
        values = []
        for seed in SEEDS:
            ckpt = checkpoint_path(RESULTS, DATASET, split, 'binary', seed, model=model)
            res = results_path(RESULTS, run_tag(DATASET, split, 'binary', seed), model=model)
            if os.path.exists(ckpt) and os.path.exists(res):
                complete += 1
                values.append(json.load(open(res))['test_metrics']['auroc'])
            elif os.path.exists(ckpt):
                interrupted += 1
        spread = (f'{st.mean(values):.4f} +- {st.stdev(values):.4f}' if len(values) > 1
                  else f'{values[0]:.4f}' if values else '--')
        print(f'{model:18s} {split:12s} {len(values):>3d}/{len(SEEDS):<3d}   {spread}')

RUN_COMPLETE = complete == TOTAL_CELLS
print(f'\ncomplete    : {complete} / {TOTAL_CELLS}')
print(f'interrupted : {interrupted}  (retrained next commit)')
print(f'time left   : {hours_left():.1f} h')
print("\nALL DONE for this run's settings." if RUN_COMPLETE else
      '\nNot done yet: download the output, update the restore dataset, commit again with RESTORE_FROM set.')
# Out:
# model              split          cells   AUROC mean +- sd
# moltrans           random         3/3     0.9220 +- 0.0000
# moltrans           cold_drug      3/3     0.6677 +- 0.0000
# moltrans           cold_target    2/3     0.8680 +- 0.0000
# moltrans           cold_pair      3/3     0.5899 +- 0.0000
#
# complete    : 11 / 12
# interrupted : 0  (retrained next commit)
# time left   : -0.0 h
#
# Not done yet: download the output, update the restore dataset, commit again with RESTORE_FROM set.

# %% [markdown]
# ## 10. Take the results with you
#
# Everything in `/kaggle/working` is saved as this version's output. The zip is the easy
# download. Add its contents to your restore dataset (as a new version) before the next
# commit, and keep a copy in Google Drive.

# %%
ZIP_NAME = f'{DATASET}_{"_".join(MODELS)}_results.zip'
# !cd {WORK} && rm -f {ZIP_NAME} && zip -qr {ZIP_NAME} results
print(f'{WORK}/{ZIP_NAME}  --  download from the Output panel')
# Out:
# /kaggle/working/davis_moltrans_results.zip  --  download from the Output panel
